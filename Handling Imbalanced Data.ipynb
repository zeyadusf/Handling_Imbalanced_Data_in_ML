# %% [markdown]
# # Handling Imbalanced Data
#
# In this notebook we will be using the **"Personal Key Indicators of Heart Disease"** dataset obtained from Kaggle website, and our main aim is to predict whether the patient has a heart disease or not, but before getting to the modeling and predicting stage we will encounter in this dataset a problem that is refered to as **"imbalanced data"** which will need to be handled; in order to create a more accurate models later on.
#
#
# But let's first illustrate the meaning of **imbalanced data**.
#
# The original link of the data set:
# https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

# %% [markdown]
# ## How can data be imbalanced?
#
# What if, we were trying to decide if someone has a **rare, but contagious disease**?
# ![image.png](attachment:image.png)
#
# According to the above image, we used "Age" and "Exposure" to predict whether or not someone has a rare, but contagious disease. If we simply predicted that no one had this rare disease, we would be correct almost all of the time.
#
# But we would misclassify every single person that has the rare disease; because our model became biased to the majority of people in the training dataset that don't have the disease, and that would be terrible.
#
# Most of the sophisticated classification algorithms or methods are expecting a relatively equal porportion of **Yeses** and **Nos** in the training dataset.
#
# Ok, now that we have a good understanding of the problem of **imbalanced data**, what can we do about it?
#
# One thing we can do about it is change the training dataset to have a more equal porportion of people with and without this disease.the best thing would be collect more data..
# ![image-2.png](attachment:image-2.png)
# ..but since this is a rare disease, that might not be an option.
#
# So, instead, if we already have a lot of data, we can do something called **"Under-Sampling"** or **Down-Scaling**. In this case, that means randomly removing people without the disease.
# ![image-3.png](attachment:image-3.png)
# By removing people that do not have the disease, we put more emphasis on correctly classifying the people that have it.
#
#
# Alternatively, we can use **"Over-Sampling"** or **Up-Scaling**. And it simply duplicates individuals that are under-represented (the minorty of people that actually have the disease).
# ![image-4.png](attachment:image-4.png)
# In this case, by adding additional copies of people with the disease, we again put more emphasis on correctly classifying the people that have it.
# <br>
# <br>
# #### Note:
# We can combine both techniques to get a more balanced training dataset.
# ![image-5.png](attachment:image-5.png)
# <br>
# <br>
# #### Also Note that:
# There are other methods or techniques that try to Under and Over-Sampling in intelligent ways, rather than just doing the process randomly. Two commonly used methods are **Undersampling using Tomek Links** and **SMOTE (Synthetic Minority Oversampling Technique)**, and we will be talking about them in more details in the next sections which will also include another techniques.
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# --------------------------------------

# %% [markdown]
# Now let's first import our dataset:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart_2020_cleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# ### No missing data.

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.describe(include = "object").T
# Out:
#                    count unique        top    freq
# HeartDisease      319795      2         No  292422
# Smoking           319795      2         No  187887
# AlcoholDrinking   319795      2         No  298018
# Stroke            319795      2         No  307726
# DiffWalking       319795      2         No  275385
# Sex               319795      2     Female  167805
# AgeCategory       319795     13      65-69   34151
# Race              319795      6      White  245212
# Diabetic          319795      4         No  269653
# PhysicalActivity  319795      2        Yes  247957
# GenHealth         319795      5  Very good  113858
# Asthma            319795      2         No  276923
# KidneyDisease     319795      2         No  308016
# SkinCancer        319795      2         No  289976

# %%
raw_df = df.copy()
df.drop_duplicates()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 0               30.0          No  Female        55-59     White      Yes
# 1                0.0          No  Female  80 or older     White       No
# 2               30.0          No    Male        65-69     White      Yes
# 3                0.0          No  Female        75-79     White       No
# 4                0.0         Yes  Female        40-44     White       No
# ...              ...         ...     ...          ...       ...      ...
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0                   Yes  Very good        5.0    Yes            No        Yes
# 1                   Yes  Very good        7.0     No            No         No
# 2                   Yes       Fair        8.0    Yes            No         No
# 3                    No       Good        6.0     No            No        Yes
# 4                   Yes  Very good        8.0     No            No         No
# ...                 ...        ...        ...    ...           ...        ...
# 319790               No       Fair        6.0    Yes            No         No
# 319791              Yes  Very good        5.0    Yes            No         No
# 319792              Yes       Good        6.0     No            No         No
# 319793               No       Good       12.0     No            No         No
# 319794              Yes       Good        8.0     No            No         No
#
# [301717 rows x 18 columns]

# %%
df.shape
# Out:
# (319795, 18)

# %%
319795-301717
# Out:
# 18078

# %% [markdown]
# #### We have 18078 duplicated records, maybe they are identical cases but since we're not planning to do any analysis at the moment, we can drop them to avoid any overfitting in our model.

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (301717, 18)

# %% [markdown]
# ### Let's check our data for outliers:

# %%
df.plot(kind = "box", figsize = (10,4), subplots = True)
# Out:
# BMI                  Axes(0.125,0.11;0.168478x0.77)
# PhysicalHealth    Axes(0.327174,0.11;0.168478x0.77)
# MentalHealth      Axes(0.529348,0.11;0.168478x0.77)
# SleepTime         Axes(0.731522,0.11;0.168478x0.77)
# dtype: object

# %%
sns.scatterplot(data=df, x=df.BMI, y=df.PhysicalHealth, hue=df.HeartDisease)
# Out:
# <Axes: xlabel='BMI', ylabel='PhysicalHealth'>
# C:\Users\raedt\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\raedt\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Let's first detect these outliers:

# %%
data = df.copy()

# %%
num_data=[]
for i in data.columns:
    if data[i].dtype==float :
        num_data.append(i)
print(num_data)
# Out:
# ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# %%
data[num_data]
# Out:
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 0       16.60             3.0          30.0        5.0
# 1       20.34             0.0           0.0        7.0
# 2       26.58            20.0          30.0        8.0
# 3       24.21             0.0           0.0        6.0
# 4       23.71            28.0           0.0        8.0
# ...       ...             ...           ...        ...
# 319790  27.41             7.0           0.0        6.0
# 319791  29.84             0.0           0.0        5.0
# 319792  24.24             0.0           0.0        6.0
# 319793  32.81             0.0           0.0       12.0
# 319794  46.56             0.0           0.0        8.0
#
# [301717 rows x 4 columns]

# %%
from scipy.stats import zscore

# %%
Z_score= zscore(data[num_data])

# %%
Z_score
# Out:
#              BMI  PhysicalHealth  MentalHealth  SleepTime
# 0      -1.830820       -0.070301      3.183766  -1.420852
# 1      -1.252600       -0.438823     -0.507054  -0.057636
# 2      -0.287869        2.017986      3.183766   0.623971
# 3      -0.654281       -0.438823     -0.507054  -0.739244
# 4      -0.731583        3.000709     -0.507054   0.623971
# ...          ...             ...           ...        ...
# 319790 -0.159547        0.421060     -0.507054  -0.739244
# 319791  0.216141       -0.438823     -0.507054  -1.420852
# 319792 -0.649643       -0.438823     -0.507054  -0.739244
# 319793  0.675316       -0.438823     -0.507054   3.350402
# 319794  2.801126       -0.438823     -0.507054   0.623971
#
# [301717 rows x 4 columns]

# %% [markdown]
# We will need to get only the absolute values for a single comparison operation:

# %%
Abs_scores = np.abs(Z_score)
Abs_scores
# Out:
#              BMI  PhysicalHealth  MentalHealth  SleepTime
# 0       1.830820        0.070301      3.183766   1.420852
# 1       1.252600        0.438823      0.507054   0.057636
# 2       0.287869        2.017986      3.183766   0.623971
# 3       0.654281        0.438823      0.507054   0.739244
# 4       0.731583        3.000709      0.507054   0.623971
# ...          ...             ...           ...        ...
# 319790  0.159547        0.421060      0.507054   0.739244
# 319791  0.216141        0.438823      0.507054   1.420852
# 319792  0.649643        0.438823      0.507054   0.739244
# 319793  0.675316        0.438823      0.507054   3.350402
# 319794  2.801126        0.438823      0.507054   0.623971
#
# [301717 rows x 4 columns]

# %%
no_outliers = (Abs_scores<3).all(axis=1)
# A function that originally returns "True" if all elements are there and there are no missing values, but 
# if we modify it a little like we did in the above code it will return "True" only when the condition is
# met.

print(no_outliers)
# Out:
# 0         False
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 319790     True
# 319791     True
# 319792     True
# 319793    False
# 319794     True
# Length: 301717, dtype: bool

# %%
data[no_outliers] 
# Now we will get only the rows with "True" values which don't have any outliers in any of their features
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1                No  20.34      No              No    Yes             0.0
# 3                No  24.21      No              No     No             0.0
# 6                No  21.63      No              No     No            15.0
# 7                No  31.64     Yes              No     No             5.0
# 8                No  26.45      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319789           No  22.22      No              No     No             0.0
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# 1                0.0          No  Female  80 or older     White
# 3                0.0          No  Female        75-79     White
# 6                0.0          No  Female        70-74     White
# 7                0.0         Yes  Female  80 or older     White
# 8                0.0          No  Female  80 or older     White
# ...              ...         ...     ...          ...       ...
# 319789           0.0          No  Female        18-24  Hispanic
# 319790           0.0         Yes    Male        60-64  Hispanic
# 319791           0.0          No    Male        35-39  Hispanic
# 319792           0.0          No  Female        45-49  Hispanic
# 319794           0.0          No  Female  80 or older  Hispanic
#
#                        Diabetic PhysicalActivity  GenHealth  SleepTime Asthma  \
# 1                            No              Yes  Very good        7.0     No
# 3                            No               No       Good        6.0     No
# 6                            No              Yes       Fair        4.0    Yes
# 7                           Yes               No       Good        9.0    Yes
# 8       No, borderline diabetes               No       Fair        5.0     No
# ...                         ...              ...        ...        ...    ...
# 319789                       No              Yes  Excellent        8.0     No
# 319790                      Yes               No       Fair        6.0    Yes
# 319791                       No              Yes  Very good        5.0    Yes
# 319792                       No              Yes       Good        6.0     No
# 319794                       No              Yes       Good        8.0     No
#
#        KidneyDisease SkinCancer
# 1                 No         No
# 3                 No        Yes
# 6                 No        Yes
# 7                 No         No
# 8                Yes         No
# ...              ...        ...
# 319789            No         No
# 319790            No         No
# 319791            No         No
# 319792            No         No
# 319794            No         No
#
# [262924 rows x 18 columns]

# %%
df.shape
# Out:
# (301717, 18)

# %%
counts = pd.DataFrame(no_outliers)
counts
# Out:
#             0
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
# ...       ...
# 319790   True
# 319791   True
# 319792   True
# 319793  False
# 319794   True
#
# [301717 rows x 1 columns]

# %%
counts[(counts==False)].count()
# Out:
# 0    38793
# dtype: int64

# %%
# We can double check by subtracting data[no_outliers].shape[0] from the original df.shape[0] 
301717-262924
# Out:
# 38793

# %%
39502/301717
# Out:
# 0.13092401157375952

# %% [markdown]
# ### 13% is almost in the allowed range, so we can drop those outliers, and that will be OK in normal cases, but in case of having an imbalanced data, it's recommended to keep the outliers.

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# ## Now we can focus on the imbalancing problem:

# %% [markdown]
# ### Let's check our data's balance:

# %%
labels = df.HeartDisease.value_counts().index
sizes = df.HeartDisease.value_counts()

plt.figure(figsize = (10,10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', textprops={'fontsize':20, 'color':"black"}, 
        explode=[0.05, 0.05])
plt.title('Heart Disease Patients Percentage',color = 'black',fontsize = 30)
plt.legend(df.HeartDisease.value_counts(), loc = 'lower right', title = 'Cases Count')
plt.show()

# %%
categ_data=[]
for i in df.columns:
    if df[i].dtype==object  :
        categ_data.append (i)
print(categ_data)
# Out:
# ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']

# %%
for ft in categ_data:
    plt.figure(figsize=(24,8))
    sns.countplot(x=df[ft],  color="#4974a5")
    plt.title(ft , fontsize=40)
    plt.xlabel(ft, fontsize=30) 
    plt.ylabel("Count", fontsize=30) 
    plt.show()

# %% [markdown]
# As we can see we have imbalanced data in so many of our features and even the target which is the most important.

# %% [markdown]
# ### As suspected our data is imbalanced, and we need to handle this situation

# %% [markdown]
# ### Let's first encode our categorical data:

# %%
from sklearn.preprocessing import LabelEncoder
le =  LabelEncoder()

# %%
for ft in categ_data:
    df[ft]=le.fit_transform(df[ft])

# %%
df
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0             3.0
# 1                  0  20.34        0                0       1             0.0
# 2                  0  26.58        1                0       0            20.0
# 3                  0  24.21        0                0       0             0.0
# 4                  0  23.71        0                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0             7.0
# 319791             0  29.84        1                0       0             0.0
# 319792             0  24.24        0                0       0             0.0
# 319793             0  32.81        0                0       0             0.0
# 319794             0  46.56        0                0       0             0.0
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0               30.0            0    0            7     5         2
# 1                0.0            0    0           12     5         0
# 2               30.0            0    1            9     5         2
# 3                0.0            0    0           11     5         0
# 4                0.0            1    0            4     5         0
# ...              ...          ...  ...          ...   ...       ...
# 319790           0.0            1    1            8     3         2
# 319791           0.0            0    1            3     3         0
# 319792           0.0            0    0            5     3         0
# 319793           0.0            0    0            1     3         0
# 319794           0.0            0    0           12     3         0
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0                      1          4        5.0       1              0
# 1                      1          4        7.0       0              0
# 2                      1          1        8.0       1              0
# 3                      0          2        6.0       0              0
# 4                      1          4        8.0       0              0
# ...                  ...        ...        ...     ...            ...
# 319790                 0          1        6.0       1              0
# 319791                 1          4        5.0       1              0
# 319792                 1          2        6.0       0              0
# 319793                 0          2       12.0       0              0
# 319794                 1          2        8.0       0              0
#
#         SkinCancer
# 0                1
# 1                0
# 2                0
# 3                1
# 4                0
# ...            ...
# 319790           0
# 319791           0
# 319792           0
# 319793           0
# 319794           0
#
# [301717 rows x 18 columns]

# %%
df.describe().T
# Out:
#                      count       mean       std    min    25%    50%    75%  \
# HeartDisease      301717.0   0.090353  0.286687   0.00   0.00   0.00   0.00
# BMI               301717.0  28.441970  6.468134  12.02  24.03  27.41  31.65
# Smoking           301717.0   0.422267  0.493921   0.00   0.00   0.00   1.00
# AlcoholDrinking   301717.0   0.071527  0.257704   0.00   0.00   0.00   0.00
# Stroke            301717.0   0.039984  0.195923   0.00   0.00   0.00   0.00
# PhysicalHealth    301717.0   3.572298  8.140656   0.00   0.00   0.00   2.00
# MentalHealth      301717.0   4.121475  8.128288   0.00   0.00   0.00   4.00
# DiffWalking       301717.0   0.147009  0.354115   0.00   0.00   0.00   0.00
# Sex               301717.0   0.470792  0.499147   0.00   0.00   0.00   1.00
# AgeCategory       301717.0   6.509408  3.584510   0.00   4.00   7.00   9.00
# Race              301717.0   4.365409  1.235817   0.00   5.00   5.00   5.00
# Diabetic          301717.0   0.316926  0.732372   0.00   0.00   0.00   0.00
# PhysicalActivity  301717.0   0.763669  0.424828   0.00   1.00   1.00   1.00
# GenHealth         301717.0   2.221217  1.511502   0.00   1.00   2.00   4.00
# SleepTime         301717.0   7.084559  1.467122   1.00   6.00   7.00   8.00
# Asthma            301717.0   0.141361  0.348394   0.00   0.00   0.00   0.00
# KidneyDisease     301717.0   0.039030  0.193667   0.00   0.00   0.00   0.00
# SkinCancer        301717.0   0.097084  0.296073   0.00   0.00   0.00   0.00
#
#                     max
# HeartDisease       1.00
# BMI               94.85
# Smoking            1.00
# AlcoholDrinking    1.00
# Stroke             1.00
# PhysicalHealth    30.00
# MentalHealth      30.00
# DiffWalking        1.00
# Sex                1.00
# AgeCategory       12.00
# Race               5.00
# Diabetic           3.00
# PhysicalActivity   1.00
# GenHealth          4.00
# SleepTime         24.00
# Asthma             1.00
# KidneyDisease      1.00
# SkinCancer         1.00

# %% [markdown]
# ### We will need to scale our features first:

# %%
df_scaled = df.copy()

# %%
# Since we have outliers in our data, let's first try the Robust scaler:
from sklearn.preprocessing import RobustScaler
rob = RobustScaler()
outliered_featuers = ["BMI", "PhysicalHealth", "MentalHealth", "SleepTime"]
for i in outliered_featuers:
    df_scaled[i] = rob.fit_transform(df_scaled[[i]])
df_scaled
# Out:
#         HeartDisease       BMI  Smoking  AlcoholDrinking  Stroke  \
# 0                  0 -1.418635        1                0       0
# 1                  0 -0.927822        0                0       1
# 2                  0 -0.108924        1                0       0
# 3                  0 -0.419948        0                0       0
# 4                  0 -0.485564        0                0       0
# ...              ...       ...      ...              ...     ...
# 319790             1  0.000000        1                0       0
# 319791             0  0.318898        1                0       0
# 319792             0 -0.416010        0                0       0
# 319793             0  0.708661        0                0       0
# 319794             0  2.513123        0                0       0
#
#         PhysicalHealth  MentalHealth  DiffWalking  Sex  AgeCategory  Race  \
# 0                  1.5           7.5            0    0            7     5
# 1                  0.0           0.0            0    0           12     5
# 2                 10.0           7.5            0    1            9     5
# 3                  0.0           0.0            0    0           11     5
# 4                 14.0           0.0            1    0            4     5
# ...                ...           ...          ...  ...          ...   ...
# 319790             3.5           0.0            1    1            8     3
# 319791             0.0           0.0            0    1            3     3
# 319792             0.0           0.0            0    0            5     3
# 319793             0.0           0.0            0    0            1     3
# 319794             0.0           0.0            0    0           12     3
#
#         Diabetic  PhysicalActivity  GenHealth  SleepTime  Asthma  \
# 0              2                 1          4       -1.0       1
# 1              0                 1          4        0.0       0
# 2              2                 1          1        0.5       1
# 3              0                 0          2       -0.5       0
# 4              0                 1          4        0.5       0
# ...          ...               ...        ...        ...     ...
# 319790         2                 0          1       -0.5       1
# 319791         0                 1          4       -1.0       1
# 319792         0                 1          2       -0.5       0
# 319793         0                 0          2        2.5       0
# 319794         0                 1          2        0.5       0
#
#         KidneyDisease  SkinCancer
# 0                   0           1
# 1                   0           0
# 2                   0           0
# 3                   0           1
# 4                   0           0
# ...               ...         ...
# 319790              0           0
# 319791              0           0
# 319792              0           0
# 319793              0           0
# 319794              0           0
#
# [301717 rows x 18 columns]

# %%
df_scaled.describe().T
# Out:
#                      count      mean       std       min      25%  50%  \
# HeartDisease      301717.0  0.090353  0.286687  0.000000  0.00000  0.0
# BMI               301717.0  0.135429  0.848837 -2.019685 -0.44357  0.0
# Smoking           301717.0  0.422267  0.493921  0.000000  0.00000  0.0
# AlcoholDrinking   301717.0  0.071527  0.257704  0.000000  0.00000  0.0
# Stroke            301717.0  0.039984  0.195923  0.000000  0.00000  0.0
# PhysicalHealth    301717.0  1.786149  4.070328  0.000000  0.00000  0.0
# MentalHealth      301717.0  1.030369  2.032072  0.000000  0.00000  0.0
# DiffWalking       301717.0  0.147009  0.354115  0.000000  0.00000  0.0
# Sex               301717.0  0.470792  0.499147  0.000000  0.00000  0.0
# AgeCategory       301717.0  6.509408  3.584510  0.000000  4.00000  7.0
# Race              301717.0  4.365409  1.235817  0.000000  5.00000  5.0
# Diabetic          301717.0  0.316926  0.732372  0.000000  0.00000  0.0
# PhysicalActivity  301717.0  0.763669  0.424828  0.000000  1.00000  1.0
# GenHealth         301717.0  2.221217  1.511502  0.000000  1.00000  2.0
# SleepTime         301717.0  0.042280  0.733561 -3.000000 -0.50000  0.0
# Asthma            301717.0  0.141361  0.348394  0.000000  0.00000  0.0
# KidneyDisease     301717.0  0.039030  0.193667  0.000000  0.00000  0.0
# SkinCancer        301717.0  0.097084  0.296073  0.000000  0.00000  0.0
#
#                       75%        max
# HeartDisease      0.00000   1.000000
# BMI               0.55643   8.850394
# Smoking           1.00000   1.000000
# AlcoholDrinking   0.00000   1.000000
# Stroke            0.00000   1.000000
# PhysicalHealth    1.00000  15.000000
# MentalHealth      1.00000   7.500000
# DiffWalking       0.00000   1.000000
# Sex               1.00000   1.000000
# AgeCategory       9.00000  12.000000
# Race              5.00000   5.000000
# Diabetic          0.00000   3.000000
# PhysicalActivity  1.00000   1.000000
# GenHealth         4.00000   4.000000
# SleepTime         0.50000   8.500000
# Asthma            0.00000   1.000000
# KidneyDisease     0.00000   1.000000
# SkinCancer        0.00000   1.000000

# %% [markdown]
# ### Now, we can apply any scaler to the whole dataset, but because we don't need to scale our target in our case here, we will scale only the features, so we can do this after droping the target (while we are getting ready for the splitting stage)

# %%
x = df_scaled.drop(columns='HeartDisease')

# %%
# We will use the minmaxscaler:
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %%
for i in x:
    x[i] = minmax.fit_transform(x[[i]])
x
# Out:
#              BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0       0.055294      1.0              0.0     0.0        0.100000
# 1       0.100447      0.0              0.0     1.0        0.000000
# 2       0.175782      1.0              0.0     0.0        0.666667
# 3       0.147169      0.0              0.0     0.0        0.000000
# 4       0.141132      0.0              0.0     0.0        0.933333
# ...          ...      ...              ...     ...             ...
# 319790  0.185802      1.0              0.0     0.0        0.233333
# 319791  0.215139      1.0              0.0     0.0        0.000000
# 319792  0.147531      0.0              0.0     0.0        0.000000
# 319793  0.250996      0.0              0.0     0.0        0.000000
# 319794  0.416999      0.0              0.0     0.0        0.000000
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                1.0          0.0  0.0     0.583333   1.0  0.666667
# 1                0.0          0.0  0.0     1.000000   1.0  0.000000
# 2                1.0          0.0  1.0     0.750000   1.0  0.666667
# 3                0.0          0.0  0.0     0.916667   1.0  0.000000
# 4                0.0          1.0  0.0     0.333333   1.0  0.000000
# ...              ...          ...  ...          ...   ...       ...
# 319790           0.0          1.0  1.0     0.666667   0.6  0.666667
# 319791           0.0          0.0  1.0     0.250000   0.6  0.000000
# 319792           0.0          0.0  0.0     0.416667   0.6  0.000000
# 319793           0.0          0.0  0.0     0.083333   0.6  0.000000
# 319794           0.0          0.0  0.0     1.000000   0.6  0.000000
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 0                    1.0       1.00   0.173913     1.0            0.0
# 1                    1.0       1.00   0.260870     0.0            0.0
# 2                    1.0       0.25   0.304348     1.0            0.0
# 3                    0.0       0.50   0.217391     0.0            0.0
# 4                    1.0       1.00   0.304348     0.0            0.0
# ...                  ...        ...        ...     ...            ...
# 319790               0.0       0.25   0.217391     1.0            0.0
# 319791               1.0       1.00   0.173913     1.0            0.0
# 319792               1.0       0.50   0.217391     0.0            0.0
# 319793               0.0       0.50   0.478261     0.0            0.0
# 319794               1.0       0.50   0.304348     0.0            0.0
#
#         SkinCancer
# 0              1.0
# 1              0.0
# 2              0.0
# 3              1.0
# 4              0.0
# ...            ...
# 319790         0.0
# 319791         0.0
# 319792         0.0
# 319793         0.0
# 319794         0.0
#
# [301717 rows x 17 columns]

# %%
x.describe().T
# Out:
#                      count      mean       std  min       25%       50%  \
# BMI               301717.0  0.198261  0.078089  0.0  0.144996  0.185802
# Smoking           301717.0  0.422267  0.493921  0.0  0.000000  0.000000
# AlcoholDrinking   301717.0  0.071527  0.257704  0.0  0.000000  0.000000
# Stroke            301717.0  0.039984  0.195923  0.0  0.000000  0.000000
# PhysicalHealth    301717.0  0.119077  0.271355  0.0  0.000000  0.000000
# MentalHealth      301717.0  0.137382  0.270943  0.0  0.000000  0.000000
# DiffWalking       301717.0  0.147009  0.354115  0.0  0.000000  0.000000
# Sex               301717.0  0.470792  0.499147  0.0  0.000000  0.000000
# AgeCategory       301717.0  0.542451  0.298709  0.0  0.333333  0.583333
# Race              301717.0  0.873082  0.247163  0.0  1.000000  1.000000
# Diabetic          301717.0  0.105642  0.244124  0.0  0.000000  0.000000
# PhysicalActivity  301717.0  0.763669  0.424828  0.0  1.000000  1.000000
# GenHealth         301717.0  0.555304  0.377875  0.0  0.250000  0.500000
# SleepTime         301717.0  0.264546  0.063788  0.0  0.217391  0.260870
# Asthma            301717.0  0.141361  0.348394  0.0  0.000000  0.000000
# KidneyDisease     301717.0  0.039030  0.193667  0.0  0.000000  0.000000
# SkinCancer        301717.0  0.097084  0.296073  0.0  0.000000  0.000000
#
#                        75%  max
# BMI               0.236991  1.0
# Smoking           1.000000  1.0
# AlcoholDrinking   0.000000  1.0
# Stroke            0.000000  1.0
# PhysicalHealth    0.066667  1.0
# MentalHealth      0.133333  1.0
# DiffWalking       0.000000  1.0
# Sex               1.000000  1.0
# AgeCategory       0.750000  1.0
# Race              1.000000  1.0
# Diabetic          0.000000  1.0
# PhysicalActivity  1.000000  1.0
# GenHealth         1.000000  1.0
# SleepTime         0.304348  1.0
# Asthma            0.000000  1.0
# KidneyDisease     0.000000  1.0
# SkinCancer        0.000000  1.0

# %% [markdown]
# ### The thumb rule is: never mess up with your test set. Always split into test and train sets BEFORE trying oversampling/undersampling techniques!
#
# Oversampling before splitting the data can allow the exact same observations to be present in both the test and train sets (Data Leakage). This can allow model to simply memorize specific data points and cause overfitting and poor generalization to the test data. Data leakage can cause you to create overly optimistic if not completely invalid predictive models.

# %% [markdown]
# ### Let's first split our dataset into train and test sets:

# %%
y = df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.3, random_state=42)

# %% [markdown]
# ####  You might noticed that we used strified splitting which is a technique used in machine learning to divide a dataset into training and testing subsets while preserving the class distribution of the target variable. It is particularly useful when dealing with imbalanced datasets, where the number of instances belonging to different classes is significantly unequal.
#
# #### The goal of stratified splitting is to ensure that the training and testing sets have similar class proportions as the original dataset. This helps to ensure that the model is trained and evaluated on representative samples from each class, which is important for achieving accurate and unbiased performance metrics.
#
# #### Here's a step-by-step explanation of how stratified splitting works
# 1. Initially, we have a dataset with labeled instances, where each instance has a feature vector and a corresponding class label.
#
# 2. The first step is to identify the unique class labels in the dataset.
#
# 3. For each class label, the stratified splitting algorithm ensures that the training and testing sets have a similar distribution of instances from that class.
#
# 4. To achieve this, the algorithm randomly samples instances from each class separately, ensuring that the ratio of class instances in the training and testing sets is consistent with the original dataset.
#
# 5. The instances selected for the training set are removed from consideration for the testing set, to avoid duplicate instances in both sets.
#
# 6. The resulting training and testing sets maintain the original class distribution, allowing for more reliable model training and evaluation.

# %% [markdown]
# ## Let's check our model before applying any oversampling or undersampling techniques:

# %% [markdown]
# ### Let's first import the remaining packages we are going to need:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

from sklearn import metrics
from sklearn.metrics import confusion_matrix,classification_report,ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.model_selection import cross_val_score, cross_validate

# %%
def evaluate_model(models, x_train, x_test, y_train, y_test):
    compare_list = []
    for index,clf in models :
        clf.fit(x_train, y_train)
        y_pred = clf.predict(x_test)
        compare_list.append((pd.Series({"Precision" : precision_score(y_test, y_pred,average='macro'),
                           "Recall" : recall_score(y_test, y_pred,average='macro'),
                           "F1" : f1_score(y_test, y_pred,average='macro'),
                           "Accuracy" : accuracy_score(y_test, y_pred),
                           "Train_Score" : clf.score((x_train),y_train),
                           "Test_Score" : clf.score((x_test), y_test)}, name = index)))
    compare_list = pd.DataFrame(compare_list).T
    return compare_list

# %%
LR = LogisticRegression()
RF = RandomForestClassifier(n_estimators=4,random_state=42)
DT = DecisionTreeClassifier(random_state=0)
KNN = KNeighborsClassifier(n_neighbors=100)
XGB = XGBClassifier()

models = [('LogR', LR), ('RandF', RF), ('DTs', DT),('KNN', KNN), ('XGB', XGB)]

# %%
def highlight(s):
    is_max = s == s.max()
    return ['background-color: blue' if v else '' for v in is_max]

# %%
result_1 = evaluate_model(models, x_train, x_test, y_train, y_test)
result_1.style.apply(highlight,axis=1)
# Out:
# <style type="text/css">
# #T_44f90_row0_col3, #T_44f90_row1_col2, #T_44f90_row2_col2, #T_44f90_row3_col3, #T_44f90_row4_col2, #T_44f90_row5_col3 {
#   background-color: blue;
# }
# </style>
# <table id="T_44f90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44f90_level0_col0" class="col_heading level0 col0" >LogR</th>
#       <th id="T_44f90_level0_col1" class="col_heading level0 col1" >RandF</th>
#       <th id="T_44f90_level0_col2" class="col_heading level0 col2" >DTs</th>
#       <th id="T_44f90_level0_col3" class="col_heading level0 col3" >KNN</th>
#       <th id="T_44f90_level0_col4" class="col_heading level0 col4" >XGB</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44f90_level0_row0" class="row_heading level0 row0" >Precision</th>
#       <td id="T_44f90_row0_col0" class="data row0 col0" >0.716365</td>
#       <td id="T_44f90_row0_col1" class="data row0 col1" >0.605636</td>
#       <td id="T_44f90_row0_col2" class="data row0 col2" >0.575108</td>
#       <td id="T_44f90_row0_col3" class="data row0 col3" >0.750186</td>
#       <td id="T_44f90_row0_col4" class="data row0 col4" >0.717305</td>
#     </tr>
#     <tr>
#       <th id="T_44f90_level0_row1" class="row_heading level0 row1" >Recall</th>
#       <td id="T_44f90_row1_col0" class="data row1 col0" >0.543354</td>
#       <td id="T_44f90_row1_col1" class="data row1 col1" >0.540273</td>
#       <td id="T_44f90_row1_col2" class="data row1 col2" >0.583992</td>
#       <td id="T_44f90_row1_col3" class="data row1 col3" >0.517122</td>
#       <td id="T_44f90_row1_col4" class="data row1 col4" >0.546982</td>
#     </tr>
#     <tr>
#       <th id="T_44f90_level0_row2" class="row_heading level0 row2" >F1</th>
#       <td id="T_44f90_row2_col0" class="data row2 col0" >0.556943</td>
#       <td id="T_44f90_row2_col1" class="data row2 col1" >0.550171</td>
#       <td id="T_44f90_row2_col2" class="data row2 col2" >0.579060</td>
#       <td id="T_44f90_row2_col3" class="data row2 col3" >0.511173</td>
#       <td id="T_44f90_row2_col4" class="data row2 col4" >0.562569</td>
#     </tr>
#     <tr>
#       <th id="T_44f90_level0_row3" class="row_heading level0 row3" >Accuracy</th>
#       <td id="T_44f90_row3_col0" class="data row3 col0" >0.910182</td>
#       <td id="T_44f90_row3_col1" class="data row3 col1" >0.896361</td>
#       <td id="T_44f90_row3_col2" class="data row3 col2" >0.853374</td>
#       <td id="T_44f90_row3_col3" class="data row3 col3" >0.910646</td>
#       <td id="T_44f90_row3_col4" class="data row3 col4" >0.910270</td>
#     </tr>
#     <tr>
#       <th id="T_44f90_level0_row4" class="row_heading level0 row4" >Train_Score</th>
#       <td id="T_44f90_row4_col0" class="data row4 col0" >0.910337</td>
#       <td id="T_44f90_row4_col1" class="data row4 col1" >0.968864</td>
#       <td id="T_44f90_row4_col2" class="data row4 col2" >0.997386</td>
#       <td id="T_44f90_row4_col3" class="data row4 col3" >0.910881</td>
#       <td id="T_44f90_row4_col4" class="data row4 col4" >0.917860</td>
#     </tr>
#     <tr>
#       <th id="T_44f90_level0_row5" class="row_heading level0 row5" >Test_Score</th>
#       <td id="T_44f90_row5_col0" class="data row5 col0" >0.910182</td>
#       <td id="T_44f90_row5_col1" class="data row5 col1" >0.896361</td>
#       <td id="T_44f90_row5_col2" class="data row5 col2" >0.853374</td>
#       <td id="T_44f90_row5_col3" class="data row5 col3" >0.910646</td>
#       <td id="T_44f90_row5_col4" class="data row5 col4" >0.910270</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### As we can see the results are not the best thing. So, let's jumb to the techniques in order to solve our main problem (imbalance).

# %% [markdown]
# ## 1st Technique: "Over-Sampling" (Randomly):
# It aims to balance class distribution by randomly increasing minority class examples by replicating them.

# %% [markdown]
# ### The following is an old way where we apply it to the whole dataset before splitting which as we discussed is not allowed anymore,. So, feel free to ignore it:

# %%
#from sklearn.utils import resample

#df["HeartDisease"].value_counts()

#df_majority = df[(dc['HeartDisease']==0)] 
#df_minority = df[(dc['HeartDisease']==1)] 

#df_minority_upsampled = resample(df_minority, replace=True, n_samples= 259620, random_state=42) 

#df_upsampled = pd.concat([dc_minority_upsampled, df_majority])

# %% [markdown]
# #### It can be done for the splitted x and y train sets, but the steps will be more slower and complicated.
#
#
# <br>
#
# ### So, we will try a better way:

# %% [markdown]
# ### There's an easier and quicker way to apply the random oversampling technique, which is importing and using the **ROSE (Random Oversampling Examples)** method from the **"imblearn"** package, as follows:

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
x_overR, y_overR = ros.fit_resample(x_train, y_train)

# %%
y_train.value_counts()
# Out:
# 0    192118
# 1     19083
# Name: HeartDisease, dtype: int64

# %%
y_overR.value_counts()
# Out:
# 0    192118
# 1    192118
# Name: HeartDisease, dtype: int64

# %%
x_train.shape
# Out:
# (211201, 17)

# %%
x_overR.shape
# Out:
# (384236, 17)

# %%
192118*2
# Out:
# 384236

# %%
result_2 = evaluate_model(models, x_overR, x_test, y_overR, y_test)
result_2.style.apply(highlight,axis=1)

# %% [markdown]
# ## 2rd Technique: "Under-Sampling" (Randomly):
# It aims to balance class distribution by randomly delete majority class examples.

# %%
# The same goes to the following so feel free to ignore it:
#dc_majority_downsampled = resample(dc_majority, replace=True, n_samples= 20673, random_state=42) 

#dc_downsampled = pd.concat([dc_minority, dc_majority_downsampled])

# %% [markdown]
# ### There's also an easier and quicker way to apply the random undersampling technique, using the undersampling method from the **"imblearn"** package, as follows:

# %%
from imblearn.over_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=42)
x_underR, y_underR = rus.fit_resample(x_train, y_train)

# %%
y_underR.value_counts()

# %%
result_3 = evaluate_model(models, x_underR, x_test, y_underR, y_test)
result_3.style.apply(highlight,axis=1)

# %% [markdown]
# #### These random techniques are are referred to as “naive resampling” methods because they assume nothing about the data. This makes them simple to implement and fast to execute, which is desirable for very large and complex datasets.
#
# #### But we should know that they are not always recommended due to the duplicates that get created during the process which might cause overfitting to the model. So, we shall be aware of data leakage.

# %% [markdown]
# ## 3rd Technique: "Over-Sampling" using SMOTE (Intelligently):
# ![image-2.png](attachment:image-2.png)
#
# <br>
# SMOTE (Synthetic Minority Oversampling Technique) is one of the most commonly used oversampling methods to solve the imbalance problem.
#
#
# SMOTE synthesises new minority instances between existing minority instances. It generates the virtual training records by linear interpolation for the minority class. These synthetic training records are generated by randomly selecting one or more of the k-nearest neighbors for each example in the minority class. After the oversampling process, the data is reconstructed and several classification models can be applied for the processed data.

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=42)
x_oversm, y_oversm = sm.fit_resample(x_train, y_train)

# %%
y_oversm.value_counts()

# %%
result_4 = evaluate_model(models, x_oversm, x_test, y_oversm, y_test)
result_4.style.apply(highlight,axis=1)

# %% [markdown]
# ## 3rd Technique: "Over-Sampling" using SMOTE (Intelligently):
# ![image.png](attachment:image.png)
# <br>
# Tomek Links is an under-sampling technique that was developed in 1976 by Ivan Tomek. It is one of a modification from Condensed Nearest Neighbors (CNN). It can be used to find desired samples of data from the majority class that is having the lowest Euclidean distance with the minority class data and then remove it.

# %%
from imblearn.under_sampling import TomekLinks

# %%
tomek = TomekLinks()
x_underT, y_underT = tomek.fit_resample(x_train, y_train)

# %%
y_underT.value_counts()

# %%
result_5 = evaluate_model(models, x_underT, x_test, y_underT, y_test)
result_5.style.apply(highlight,axis=1)

# %% [markdown]
# ## 4th Technique: Combining both Over-Sampling "SMOTE" and Under-Sampling "Tomek Links" (Intelligently): Using "SMOTETomek"
#
#
# <br>
#
# A combination of over-sampling the minority (abnormal) class and under-sampling the majority (normal) class can achieve better classifier performance than only under-sampling the majority class. This method was first introduced by Batista et al. (2003).
# <br><br>
# The process of SMOTE-Tomek Links is as follows.
#
# 1.Start of SMOTE: choose random data from the minority class.
# <br>
# 2. Calculate the distance between the random data and its k nearest neighbors.
# <br>
# 3. Multiply the difference with a random number between 0 and 1, then add the result to the minority class as a synthetic sample.<br>
# 4. Repeat step number 2–3 until the desired proportion of minority class is met (End of SMOTE).<br>
# 5. Start of Tomek Links: choose random data from the majority class.<br>
# 6. If the random data’s nearest neighbor is the data from the minority class (i.e. create the Tomek Link), then remove the Tomek Link.
